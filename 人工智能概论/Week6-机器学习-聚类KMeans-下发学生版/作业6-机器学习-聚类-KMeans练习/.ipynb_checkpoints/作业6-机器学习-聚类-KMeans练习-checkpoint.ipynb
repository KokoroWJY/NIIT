# %% [markdown]
# # 作业6-机器学习-聚类-KMeans练习
# **作业要求：**
#
# - 在Python Jupyter中回答，**需运行出结果**。
# - 网页-打印-另存为pdf，命名：**作业6-班级-学号后两位-姓名.pdf**
# - 按时上传职教云，**过期不补**。

# %% [markdown]
# ## 任务说明
# - 小明是一家超市的老板。通过会员卡，有一些关于客户的基本数据，如客户ID，年龄，性别，年收入和消费分数。小明想要了解怎么样的顾客可以很容易地聚集在一起(目标顾客)，以便可以给营销团队以灵感并相应地计划策略。
# - 用到的数据集，含包有关客户的基本信息（ID，年龄，性别，收入，支出分数）。共有5个字段200行
#
# ## 任务内容：
#
# 1. 数据加载
# 2. 数据预处理
# 3. 构建模型
# 4. 模型评价和选择最优解
# 5. 数据可视化

# %%
# 导入包

# %% [markdown]
# ### 1. 加载数据

# %%
# 数据导入
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %% [markdown]
# ### 2. 数据预处理

# %%
# 此案例仅选取后三列数值项作为特征，删除ID和性别, 共200条数据
# Out:
#    Age  Annual Income (k$)  Spending Score (1-100)
# 0   19                  15                      39
# 1   21                  15                      81
# 2   20                  16                       6
# 3   23                  16                      77
# 4   31                  17                      40

# %%
# 三维数据可视化
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### 3. 构建模型

# %%
# 从K=2，尝试2,3,4...10个簇
# 轮廓系数列表
# 簇内平方和列表


    
print('轮廓系数分别是：',sc)
print('簇内平方和分别是：', wcss)
# Out:
# 轮廓系数分别是： [0.293166070535953, 0.3839349967742105, 0.40546302077733304, 0.44428597560893024, 0.4523443947724053, 0.438278833939321, 0.42977587111050725, 0.41443894953771165, 0.3791225941548676]
# 簇内平方和分别是： [212840.16982097193, 143342.75157170597, 104366.151455562, 75350.77917248776, 58300.443321590676, 51153.28301584004, 44312.468812077226, 40894.989782139775, 37463.474139079306]

# %%
# 轮廓系数和簇内平方和的可视化
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0, 0.5, 'Within Clustering Sum Squarts')

# %% [markdown]
# ### 选择 K = 6 进行建模

# %%
# （1）初始化聚类器，指定分簇的数量K=6

# （2）训练数据

# （3）得到簇中心向量

print('计算得到的6个簇的中心分别是：\n',)
print('共计迭代次数:',)

# （4）每个样本所属的类

print('每个样本所属的簇：\n', )

# (5) 轮廓系数
print('模型的轮廓系数为：\n', )
# Out:
# 计算得到的6个簇的中心分别是：
#  [[56.15555556 53.37777778 49.08888889]
#  [32.69230769 86.53846154 82.12820513]
#  [25.27272727 25.72727273 79.36363636]
#  [41.68571429 88.22857143 17.28571429]
#  [27.         56.65789474 49.13157895]
#  [44.14285714 25.14285714 19.52380952]]
# 共计迭代次数: 5
# 每个样本所属的簇：
#  [5 2 5 2 5 2 5 2 5 2 5 2 5 2 5 2 5 2 5 2 5 2 5 2 5 2 5 2 5 2 5 2 5 2 5 2 5
#  2 5 2 0 2 0 4 5 2 0 4 4 4 0 4 4 0 0 0 0 0 4 0 0 4 0 0 0 4 0 0 4 4 0 0 0 0
#  0 4 0 4 4 0 0 4 0 0 4 0 0 4 4 0 0 4 0 4 4 4 0 4 0 4 4 0 0 4 0 4 0 0 0 0 0
#  4 4 4 4 4 0 0 0 0 4 4 4 1 4 1 3 1 3 1 3 1 4 1 3 1 3 1 3 1 3 1 4 1 3 1 3 1
#  3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3
#  1 3 1 3 1 3 1 3 1 3 1 3 1 3 1]
# 模型的轮廓系数为：
#  0.4523443947724053

# %%
# 将三维数据点画图显示出来
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## 选做：试试看这个数据集的聚类

# %%
from sklearn.datasets import make_circles
# X: 二维数据
# y：真实的分类情况
X, y = make_circles(n_samples=750, factor=0.3, noise=0.1)

# %%
# （1）初始化聚类器，指定分簇的数量K=2

# （2）训练数据

# （3）得到簇中心向量

print('计算得到的2个簇的中心分别是：\n',)
# （4）每个样本所属的类

# (5) 轮廓系数
print('模型的轮廓系数为：\n', )
# Out:
# 计算得到的2个簇的中心分别是：
#  [[ 0.00587147 -0.45291997]
#  [-0.006929    0.3922687 ]]
# 模型的轮廓系数为：
#  0.29568361303366136

# %%
# 将三维数据点画图显示出来

# %% [markdown]
# ## 我们知道应该分两个簇，内圈一个，外圈一个，但是KMeans解决不了这个问题，得试试其他算法了，《机器学习与深度学习》的课上请认真学习哦。
